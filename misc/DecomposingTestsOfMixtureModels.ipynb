# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
c0 = [.1,.2,.7]
c1 = [.2,.5,.3]

# %%
def f0(x):
    return np.exp(x*-1)
def f1(x):
    return np.cos(x)**2+.01
def f2(x):
    return np.exp(-(x-2)**2/2)
fs = [f0, f1, f2]

# %%
def F0(x):
    sum = 0.
    for i,c in enumerate(c0):
        sum+= c*fs[i](x)
    return sum
def F1(x):
    sum = 0.
    for i,c in enumerate(c1):
        sum+= c*fs[i](x)
    return sum

# %%
xarray = np.linspace(0,5,100)

# %%
plt.plot(xarray,f0(xarray))
plt.plot(xarray,f1(xarray))
plt.plot(xarray,f2(xarray))
plt.plot(xarray,F0(xarray))
plt.plot(xarray,F1(xarray))

# %%
plt.plot(xarray,F0(xarray)/F1(xarray))

# %%
def altRatio(x):
    sum = 0.
    for i,c in enumerate(c0):
        if(c==0):
            continue
        innerSum = 0.
        for j,cp in enumerate(c1):
            innerSum+= cp/c*fs[j](x)/fs[i](x)
        sum+=1./innerSum
    return sum

# %%
plt.plot(xarray,altRatio(xarray))

# %%
plt.plot(xarray,altRatio(xarray)-F0(xarray)/F1(xarray))

# %%
plt.plot(xarray,fs[0](xarray)/fs[1](xarray))

# %%
plt.plot(xarray,fs[0](xarray)/fs[2](xarray))

# %%
plt.plot(xarray,fs[1](xarray)/fs[2](xarray))

# %% [markdown]
# # Do it again with one component set to zero

# %%
c0 = [.99,.01,0.]
c1 = [.98,.01,.01]

# %%
plt.plot(xarray,F0(xarray))
plt.plot(xarray,np.log(F1(xarray)/F0(xarray)))

# %%
plt.plot(xarray,altRatio(xarray)-F0(xarray)/F1(xarray))
